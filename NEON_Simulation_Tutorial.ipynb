# %% [markdown]
# # Tutorial 1: CTSM Simulations at NEON Tower Sites
#
# This tutorial is an introduction to running the Community Terrestrial Systems Model (CTSM) at NEON tower sites.  It will guide you through running a simulation and provides example visualization of the simulation results. Once you complete a NEON tower simulation in this tutorial, you can use the 'NEON_Visualization_Tutorial' to explore observation and model data further.
# <br><br>
#
# **A few notes about the model:** There are several configuration options of CTSM, and throughout this tutorial we will use the Community Land Model (CLM) configuration which is the climate and biogeochemistry mode of CTSM. Throughout the rest of this tutorial, we refer to the model as CLM and will use version 5.1 with active biogeochemistry (CLM5.1-BGC).
#
# Additional information about CTSM and CLM is available [on the website](https://www.cesm.ucar.edu/models/cesm2/land/), including [technical documentation](https://escomp.github.io/ctsm-docs/versions/master/html/tech_note/index.html), a [user's guide](https://escomp.github.io/ctsm-docs/versions/master/html/users_guide/index.html), and a [quickstart guide](https://escomp.github.io/CESM/release-cesm2/quickstart.html#create-a-case) for running various model configurations beyond what is covered in this tutorial.
# <br><br>
#
# **Questions about this tutorial?** Please post them on the [CTSM forum in the CESM Bulletin Board](https://bb.cgd.ucar.edu/cesm/forums/ctsm-clm-mosart-rtm.134/). Note that this resource will require you to register and log in so that you can be notified of responses to your inquiries. You can also file issues on the [NCAR-NEON GitHub repository](https://github.com/NCAR/NEON-visualization).
# ***

# %% [markdown]
# ## In this tutorial
#
# The tutorial has several components. Below you will find steps to:
# 1. Set up and run a simulation
# 2. Locate CLM model data
# 3. Look at plots of simulated soil temperature and moisture data

# %% [markdown]
# ***
# **This tutorial uses a Jupyter Notebook.** A Jupyter Notebook is an interactive computing environment that enables the creation and sharing of documents that contain discrete cells of text or documentation and executable code, including plots. It allows users to access, run, and edit the code in a browser. To interact with this notebook:
#
# - Execute or "run" cells of executable code (cells denoted with '[ ]:') using the play button in the menu at the top (see below image)
#
# - The results of running code, such as plots, will appear below that cell
#
# - Each step must be followed in order, otherwise you may encounter errors
#
# ![run cell](https://problemsolvingwithpython.com/02-Jupyter-Notebooks/images/run_cell.png)
#
# For more information on Jupyter notebooks please see the [Jupyter Notebook Quick Start Guide](https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html).
# ***

# %% [markdown]
# <h2> 1. Set up and run a simulation</h2>
#
# *This step guides you through running a CLM model simulation for a NEON flux tower using meteorology observations from the tower. Here, the many steps to run CLM are condensed into a single function. We are developing an additional advanced tutorial (coming soon!) with instructions for using different model configurations and modifying code.* <br>
#
# ***
# <h4>1.1 Select a NEON tower site to simulate.</h4>
#
# NEON towers currently available for simulation include:
#
# >ABBY, BART, BLAN, CPER, DCFS, DSNY, GRSM, HARV, JERC, JORN, KONZ, MOAB, NOGP, OAES, ORNL, OSBS, SCBI, SERC, SOAP, SRER, STEI, TALL, TREE, UKFS, UNDE, WOOD.
#
# The [NEON website](https://www.neonscience.org/field-sites/explore-field-sites) describes tower sites in more detail.
#
# Before running the below code, keep in mind:
# - The executable code below selects the **ABBY** site for simulation. If you would like to simulate a different tower, select the NEON tower from the above list and change the 4-character site name inside the quotes below.
# - The site must be defined correctly so you do not get an error in the next step.
#     - use all capital letters
#     - double-check that the letters match one of the above site names
#
# *Execute the the cell below by clicking on the play button in the menu bar above.*

# %%
#Change the 4-character NEON site below.
neon_site= "ABBY"

import os
os.environ['site'] = neon_site

# %% [markdown]
# ***
# <h4>1.2 Create and run a NEON tower site simulation.</h4>
#
# The executable code below runs a python script, `run_neon.py`. This script:
#
# * creates (`create_newcase`)
# * sets up (`case.setup`)
# * compiles (`case.build`)
# * runs (`case.submit`)
#
# a simulation for the tower site you specified above for all years that tower meteorology data are available. The text in parentheses show the commands that are typically required to set up and run a simulation. These steps are automated for you in the `run_neon` script.
#
# *Run the cell below.* Note that this step downloads the input data (~2.5GB) required for the model simulation and may therefore take several minutes to complete running, so please be patient. Many things will print below the cell as data are downloaded and the model compiles. You might see lines that say 'ERROR' or 'file not found'; this is ok if the simulation continues running to completion.

# %%
run_neon --neon-sites $site --output-root ~/CLM-NEON
# Out:
# /opt/ncar/cesm/tools/site_and_regional/run_neon.py:535: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if run_type is not "transient":
# ---- building a base case -------
# ---- creating a base case -------
# ---- base case created ------
# ---- base case setup ------
# ---- base case build ------
# WARNING: No .input_data_list files found in dir 'Buildconf'
# Time required to building the base case: 207.6625852584839 s.
# using this version: latest
# ---- cloning the base case in /home/user/CLM-NEON/ABBY.transient
# Model ctsm missing file megan_factors_file = '/home/user/inputdata/atm/cam/chem/trop_mozart/emis/megan21_emis_factors_78pft_c20161108.nc'
# wget failed with output:  and errput --2025-02-27 04:28:39--  https://storage.neonscience.org/neon-ncar/NEON/atm/cam/chem/trop_mozart/emis/megan21_emis_factors_78pft_c20161108.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/atm/cam/chem/trop_mozart/emis/megan21_emis_factors_78pft_c20161108.nc [following]
# --2025-02-27 04:28:40--  https://storage.googleapis.com/neon-ncar/NEON/atm/cam/chem/trop_mozart/emis/megan21_emis_factors_78pft_c20161108.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:40 ERROR 404: Not Found.
#
# Model ctsm missing file stream_fldfilename_lightng = '/home/user/inputdata/atm/datm7/NASA_LIS/clmforc.Li_2016_climo1995-2013.360x720.lnfm_Total_NEONarea_c210625.nc'
# wget failed with output:  and errput --2025-02-27 04:28:40--  https://storage.neonscience.org/neon-ncar/NEON/atm/datm7/NASA_LIS/clmforc.Li_2016_climo1995-2013.360x720.lnfm_Total_NEONarea_c210625.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/NASA_LIS/clmforc.Li_2016_climo1995-2013.360x720.lnfm_Total_NEONarea_c210625.nc [following]
# --2025-02-27 04:28:40--  https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/NASA_LIS/clmforc.Li_2016_climo1995-2013.360x720.lnfm_Total_NEONarea_c210625.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:41 ERROR 404: Not Found.
#
# Model ctsm missing file stream_meshfile_lightng = '/home/user/inputdata/atm/datm7/NASA_LIS/ESMF_MESH.Li_2016.360x720.NEONarea_cdf5_c221104.nc'
# wget failed with output:  and errput --2025-02-27 04:28:41--  https://storage.neonscience.org/neon-ncar/NEON/atm/datm7/NASA_LIS/ESMF_MESH.Li_2016.360x720.NEONarea_cdf5_c221104.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/NASA_LIS/ESMF_MESH.Li_2016.360x720.NEONarea_cdf5_c221104.nc [following]
# --2025-02-27 04:28:41--  https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/NASA_LIS/ESMF_MESH.Li_2016.360x720.NEONarea_cdf5_c221104.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:41 ERROR 404: Not Found.
#
# Model ctsm missing file stream_fldfilename_ch4finundated = '/home/user/inputdata/lnd/clm2/paramdata/finundated_inversiondata_0.9x1.25_c170706.nc'
# wget failed with output:  and errput --2025-02-27 04:28:41--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1.25_c170706.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1.25_c170706.nc [following]
# --2025-02-27 04:28:41--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1.25_c170706.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:42 ERROR 404: Not Found.
#
# Model ctsm missing file stream_meshfile_ch4finundated = '/home/user/inputdata/lnd/clm2/paramdata/finundated_inversiondata_0.9x1_ESMFmesh_cdf5_130621.nc'
# wget failed with output:  and errput --2025-02-27 04:28:42--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1_ESMFmesh_cdf5_130621.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1_ESMFmesh_cdf5_130621.nc [following]
# --2025-02-27 04:28:42--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1_ESMFmesh_cdf5_130621.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:42 ERROR 404: Not Found.
#
# Model ctsm missing file stream_meshfile_popdens = '/home/user/inputdata/lnd/clm2/firedata/clmforc.Li_2017_HYDEv3.2_CMIP6_hdm_0.5x0_ESMFmesh_cdf5_100621.nc'
# wget failed with output:  and errput --2025-02-27 04:28:42--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2017_HYDEv3.2_CMIP6_hdm_0.5x0_ESMFmesh_cdf5_100621.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2017_HYDEv3.2_CMIP6_hdm_0.5x0_ESMFmesh_cdf5_100621.nc [following]
# --2025-02-27 04:28:43--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2017_HYDEv3.2_CMIP6_hdm_0.5x0_ESMFmesh_cdf5_100621.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:43 ERROR 404: Not Found.
#
# Model ctsm missing file stream_fldfilename_popdens = '/home/user/inputdata/lnd/clm2/firedata/clmforc.Li_2018_SSP3_CMIP6_hdm_0.5x0.5_AVHRR_simyr1850-2100_c181205.nc'
# wget failed with output:  and errput --2025-02-27 04:28:43--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2018_SSP3_CMIP6_hdm_0.5x0.5_AVHRR_simyr1850-2100_c181205.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2018_SSP3_CMIP6_hdm_0.5x0.5_AVHRR_simyr1850-2100_c181205.nc [following]
# --2025-02-27 04:28:43--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2018_SSP3_CMIP6_hdm_0.5x0.5_AVHRR_simyr1850-2100_c181205.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:43 ERROR 404: Not Found.
#
# Model ctsm missing file finidat = '/home/user/inputdata/lnd/clm2/initdata_map/clmi.I2000Clm50BgcCrop.2011-01-01.1.9x2.5_gx1v7_gl4_simyr2000_c190312.nc'
# wget failed with output:  and errput --2025-02-27 04:28:43--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/initdata_map/clmi.I2000Clm50BgcCrop.2011-01-01.1.9x2.5_gx1v7_gl4_simyr2000_c190312.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/initdata_map/clmi.I2000Clm50BgcCrop.2011-01-01.1.9x2.5_gx1v7_gl4_simyr2000_c190312.nc [following]
# --2025-02-27 04:28:44--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/initdata_map/clmi.I2000Clm50BgcCrop.2011-01-01.1.9x2.5_gx1v7_gl4_simyr2000_c190312.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:44 ERROR 404: Not Found.
#
# Model ctsm missing file fsnowoptics = '/home/user/inputdata/lnd/clm2/snicardata/snicar_optics_5bnd_c090915.nc'
# wget failed with output:  and errput --2025-02-27 04:28:44--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/snicardata/snicar_optics_5bnd_c090915.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/snicardata/snicar_optics_5bnd_c090915.nc [following]
# --2025-02-27 04:28:44--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/snicardata/snicar_optics_5bnd_c090915.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:44 ERROR 404: Not Found.
#
# Model ctsm missing file paramfile = '/home/user/inputdata/lnd/clm2/paramdata/ctsm51_params.c211112.nc'
# wget failed with output:  and errput --2025-02-27 04:28:45--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/paramdata/ctsm51_params.c211112.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/ctsm51_params.c211112.nc [following]
# --2025-02-27 04:28:45--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/ctsm51_params.c211112.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:45 ERROR 404: Not Found.
#
# Model ctsm missing file fsnowaging = '/home/user/inputdata/lnd/clm2/snicardata/snicar_drdt_bst_fit_60_c070416.nc'
# wget failed with output:  and errput --2025-02-27 04:28:45--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/snicardata/snicar_drdt_bst_fit_60_c070416.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/snicardata/snicar_drdt_bst_fit_60_c070416.nc [following]
# --2025-02-27 04:28:45--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/snicardata/snicar_drdt_bst_fit_60_c070416.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:46 ERROR 404: Not Found.
#
# Model ctsm missing file fsurdat = '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc'
# wget failed with output:  and errput --2025-02-27 04:28:46--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc [following]
# --2025-02-27 04:28:46--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:46 ERROR 404: Not Found.
#
# Model ctsm missing file stream_meshfile_urbantv = '/home/user/inputdata/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1_ESMFmesh_cdf5_100621.nc'
# wget failed with output:  and errput --2025-02-27 04:28:46--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1_ESMFmesh_cdf5_100621.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1_ESMFmesh_cdf5_100621.nc [following]
# --2025-02-27 04:28:47--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1_ESMFmesh_cdf5_100621.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:47 ERROR 404: Not Found.
#
# Model ctsm missing file stream_fldfilename_urbantv = '/home/user/inputdata/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1.25_simyr1849-2106_c160923.nc'
# wget failed with output:  and errput --2025-02-27 04:28:47--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1.25_simyr1849-2106_c160923.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1.25_simyr1849-2106_c160923.nc [following]
# --2025-02-27 04:28:47--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1.25_simyr1849-2106_c160923.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:47 ERROR 404: Not Found.
#
# Model ctsm missing file stream_meshfile_ndep = '/home/user/inputdata/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc'
# wget failed with output:  and errput --2025-02-27 04:28:47--  https://storage.neonscience.org/neon-ncar/NEON/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc [following]
# --2025-02-27 04:28:48--  https://storage.googleapis.com/neon-ncar/NEON/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:48 ERROR 404: Not Found.
#
# Model ctsm missing file stream_fldfilename_ndep = '/home/user/inputdata/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc'
# wget failed with output:  and errput --2025-02-27 04:28:48--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc [following]
# --2025-02-27 04:28:48--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:49 ERROR 404: Not Found.
#
# varname datafiles is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
# varname datafiles is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
# Model ctsm missing file stream_meshfile_popdens = '/home/user/inputdata/lnd/clm2/firedata/clmforc.Li_2017_HYDEv3.2_CMIP6_hdm_0.5x0_ESMFmesh_cdf5_100621.nc'
# wget failed with output:  and errput --2025-02-27 04:28:52--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2017_HYDEv3.2_CMIP6_hdm_0.5x0_ESMFmesh_cdf5_100621.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2017_HYDEv3.2_CMIP6_hdm_0.5x0_ESMFmesh_cdf5_100621.nc [following]
# --2025-02-27 04:28:52--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2017_HYDEv3.2_CMIP6_hdm_0.5x0_ESMFmesh_cdf5_100621.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:53 ERROR 404: Not Found.
#
# Model ctsm missing file stream_fldfilename_popdens = '/home/user/inputdata/lnd/clm2/firedata/clmforc.Li_2018_SSP3_CMIP6_hdm_0.5x0.5_AVHRR_simyr1850-2100_c181205.nc'
# wget failed with output:  and errput --2025-02-27 04:28:53--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2018_SSP3_CMIP6_hdm_0.5x0.5_AVHRR_simyr1850-2100_c181205.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2018_SSP3_CMIP6_hdm_0.5x0.5_AVHRR_simyr1850-2100_c181205.nc [following]
# --2025-02-27 04:28:53--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/firedata/clmforc.Li_2018_SSP3_CMIP6_hdm_0.5x0.5_AVHRR_simyr1850-2100_c181205.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:53 ERROR 404: Not Found.
#
# Model ctsm missing file stream_fldfilename_ndep = '/home/user/inputdata/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc'
# wget failed with output:  and errput --2025-02-27 04:28:53--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc [following]
# --2025-02-27 04:28:54--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:54 ERROR 404: Not Found.
#
# Model ctsm missing file stream_meshfile_ndep = '/home/user/inputdata/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc'
# wget failed with output:  and errput --2025-02-27 04:28:54--  https://storage.neonscience.org/neon-ncar/NEON/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc [following]
# --2025-02-27 04:28:54--  https://storage.googleapis.com/neon-ncar/NEON/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:54 ERROR 404: Not Found.
#
# Model ctsm missing file megan_factors_file = '/home/user/inputdata/atm/cam/chem/trop_mozart/emis/megan21_emis_factors_78pft_c20161108.nc'
# wget failed with output:  and errput --2025-02-27 04:28:54--  https://storage.neonscience.org/neon-ncar/NEON/atm/cam/chem/trop_mozart/emis/megan21_emis_factors_78pft_c20161108.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/atm/cam/chem/trop_mozart/emis/megan21_emis_factors_78pft_c20161108.nc [following]
# --2025-02-27 04:28:55--  https://storage.googleapis.com/neon-ncar/NEON/atm/cam/chem/trop_mozart/emis/megan21_emis_factors_78pft_c20161108.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:55 ERROR 404: Not Found.
#
# Model ctsm missing file stream_fldfilename_urbantv = '/home/user/inputdata/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1.25_simyr1849-2106_c160923.nc'
# wget failed with output:  and errput --2025-02-27 04:28:55--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1.25_simyr1849-2106_c160923.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1.25_simyr1849-2106_c160923.nc [following]
# --2025-02-27 04:28:55--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1.25_simyr1849-2106_c160923.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:56 ERROR 404: Not Found.
#
# Model ctsm missing file stream_meshfile_urbantv = '/home/user/inputdata/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1_ESMFmesh_cdf5_100621.nc'
# wget failed with output:  and errput --2025-02-27 04:28:56--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1_ESMFmesh_cdf5_100621.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1_ESMFmesh_cdf5_100621.nc [following]
# --2025-02-27 04:28:56--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1_ESMFmesh_cdf5_100621.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:56 ERROR 404: Not Found.
#
# Model ctsm missing file stream_fldfilename_lightng = '/home/user/inputdata/atm/datm7/NASA_LIS/clmforc.Li_2016_climo1995-2013.360x720.lnfm_Total_NEONarea_c210625.nc'
# wget failed with output:  and errput --2025-02-27 04:28:56--  https://storage.neonscience.org/neon-ncar/NEON/atm/datm7/NASA_LIS/clmforc.Li_2016_climo1995-2013.360x720.lnfm_Total_NEONarea_c210625.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/NASA_LIS/clmforc.Li_2016_climo1995-2013.360x720.lnfm_Total_NEONarea_c210625.nc [following]
# --2025-02-27 04:28:56--  https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/NASA_LIS/clmforc.Li_2016_climo1995-2013.360x720.lnfm_Total_NEONarea_c210625.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:57 ERROR 404: Not Found.
#
# Model ctsm missing file stream_meshfile_lightng = '/home/user/inputdata/atm/datm7/NASA_LIS/ESMF_MESH.Li_2016.360x720.NEONarea_cdf5_c221104.nc'
# wget failed with output:  and errput --2025-02-27 04:28:57--  https://storage.neonscience.org/neon-ncar/NEON/atm/datm7/NASA_LIS/ESMF_MESH.Li_2016.360x720.NEONarea_cdf5_c221104.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/NASA_LIS/ESMF_MESH.Li_2016.360x720.NEONarea_cdf5_c221104.nc [following]
# --2025-02-27 04:28:57--  https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/NASA_LIS/ESMF_MESH.Li_2016.360x720.NEONarea_cdf5_c221104.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:57 ERROR 404: Not Found.
#
# Model ctsm missing file fsurdat = '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc'
# wget failed with output:  and errput --2025-02-27 04:28:57--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc [following]
# --2025-02-27 04:28:58--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:58 ERROR 404: Not Found.
#
# Model ctsm missing file fsnowaging = '/home/user/inputdata/lnd/clm2/snicardata/snicar_drdt_bst_fit_60_c070416.nc'
# wget failed with output:  and errput --2025-02-27 04:28:58--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/snicardata/snicar_drdt_bst_fit_60_c070416.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/snicardata/snicar_drdt_bst_fit_60_c070416.nc [following]
# --2025-02-27 04:28:58--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/snicardata/snicar_drdt_bst_fit_60_c070416.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:58 ERROR 404: Not Found.
#
# Model ctsm missing file fsnowoptics = '/home/user/inputdata/lnd/clm2/snicardata/snicar_optics_5bnd_c090915.nc'
# wget failed with output:  and errput --2025-02-27 04:28:58--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/snicardata/snicar_optics_5bnd_c090915.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/snicardata/snicar_optics_5bnd_c090915.nc [following]
# --2025-02-27 04:28:59--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/snicardata/snicar_optics_5bnd_c090915.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:28:59 ERROR 404: Not Found.
#
# Model ctsm missing file paramfile = '/home/user/inputdata/lnd/clm2/paramdata/ctsm51_params.c211112.nc'
# wget failed with output:  and errput --2025-02-27 04:28:59--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/paramdata/ctsm51_params.c211112.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/ctsm51_params.c211112.nc [following]
# --2025-02-27 04:28:59--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/ctsm51_params.c211112.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:29:00 ERROR 404: Not Found.
#
# Model ctsm missing file finidat = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/lnd/ctsm/initdata/ABBY.2022-11-11.clm2.r.0318-01-01-00000.nc'
# Model ctsm missing file stream_fldfilename_ch4finundated = '/home/user/inputdata/lnd/clm2/paramdata/finundated_inversiondata_0.9x1.25_c170706.nc'
# wget failed with output:  and errput --2025-02-27 04:29:00--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1.25_c170706.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1.25_c170706.nc [following]
# --2025-02-27 04:29:01--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1.25_c170706.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:29:01 ERROR 404: Not Found.
#
# Model ctsm missing file stream_meshfile_ch4finundated = '/home/user/inputdata/lnd/clm2/paramdata/finundated_inversiondata_0.9x1_ESMFmesh_cdf5_130621.nc'
# wget failed with output:  and errput --2025-02-27 04:29:01--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1_ESMFmesh_cdf5_130621.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1_ESMFmesh_cdf5_130621.nc [following]
# --2025-02-27 04:29:01--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/paramdata/finundated_inversiondata_0.9x1_ESMFmesh_cdf5_130621.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:29:02 ERROR 404: Not Found.
#
# Model datm missing file file1 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-01.nc'
# Model datm missing file file2 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-02.nc'
# Model datm missing file file3 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-03.nc'
# Model datm missing file file4 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-04.nc'
# Model datm missing file file5 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-05.nc'
# Model datm missing file file6 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-06.nc'
# Model datm missing file file7 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-07.nc'
# Model datm missing file file8 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-08.nc'
# Model datm missing file file9 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-09.nc'
# Model datm missing file file10 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-10.nc'
# Model datm missing file file11 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-11.nc'
# Model datm missing file file12 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2018-12.nc'
# Model datm missing file file13 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-01.nc'
# Model datm missing file file14 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-02.nc'
# Model datm missing file file15 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-03.nc'
# Model datm missing file file16 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-04.nc'
# Model datm missing file file17 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-05.nc'
# Model datm missing file file18 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-06.nc'
# Model datm missing file file19 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-07.nc'
# Model datm missing file file20 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-08.nc'
# Model datm missing file file21 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-09.nc'
# Model datm missing file file22 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-10.nc'
# Model datm missing file file23 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-11.nc'
# Model datm missing file file24 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2019-12.nc'
# Model datm missing file file25 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-01.nc'
# Model datm missing file file26 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-02.nc'
# Model datm missing file file27 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-03.nc'
# Model datm missing file file28 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-04.nc'
# Model datm missing file file29 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-05.nc'
# Model datm missing file file30 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-06.nc'
# Model datm missing file file31 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-07.nc'
# Model datm missing file file32 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-08.nc'
# Model datm missing file file33 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-09.nc'
# Model datm missing file file34 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-10.nc'
# Model datm missing file file35 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-11.nc'
# Model datm missing file file36 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2020-12.nc'
# Model datm missing file file37 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-01.nc'
# Model datm missing file file38 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-02.nc'
# Model datm missing file file39 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-03.nc'
# Model datm missing file file40 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-04.nc'
# Model datm missing file file41 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-05.nc'
# Model datm missing file file42 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-06.nc'
# Model datm missing file file43 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-07.nc'
# Model datm missing file file44 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-08.nc'
# Model datm missing file file45 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-09.nc'
# Model datm missing file file46 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-10.nc'
# Model datm missing file file47 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-11.nc'
# Model datm missing file file48 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2021-12.nc'
# Model datm missing file file49 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2022-01.nc'
# Model datm missing file file50 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2022-02.nc'
# Model datm missing file file51 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2022-03.nc'
# Model datm missing file file52 = '/home/user/CLM-NEON/ABBY.transient/run/inputdata/atm/cdeps/v2/ABBY/ABBY_atm_2022-04.nc'
# Model datm missing file mesh = '/home/user/inputdata/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc'
# wget failed with output:  and errput --2025-02-27 04:29:40--  https://storage.neonscience.org/neon-ncar/NEON/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc [following]
# --2025-02-27 04:29:40--  https://storage.googleapis.com/neon-ncar/NEON/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:29:40 ERROR 404: Not Found.
#
# Model datm missing file file1 = '/home/user/inputdata/atm/cam/chem/trop_mozart_aero/aero/aerodep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.001_2018-2030_monthly_0.9x1.25_c210826.nc'
# wget failed with output:  and errput --2025-02-27 04:29:40--  https://storage.neonscience.org/neon-ncar/NEON/atm/cam/chem/trop_mozart_aero/aero/aerodep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.001_2018-2030_monthly_0.9x1.25_c210826.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/atm/cam/chem/trop_mozart_aero/aero/aerodep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.001_2018-2030_monthly_0.9x1.25_c210826.nc [following]
# --2025-02-27 04:29:40--  https://storage.googleapis.com/neon-ncar/NEON/atm/cam/chem/trop_mozart_aero/aero/aerodep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.001_2018-2030_monthly_0.9x1.25_c210826.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:29:41 ERROR 404: Not Found.
#
# Model datm missing file file1 = '/home/user/inputdata/lnd/clm2/ndepdata/fndep_clm_f09_g17.CMIP6-SSP3-7.0-WACCM_2018-2030_monthly_c210826.nc'
# wget failed with output:  and errput --2025-02-27 04:29:41--  https://storage.neonscience.org/neon-ncar/NEON/lnd/clm2/ndepdata/fndep_clm_f09_g17.CMIP6-SSP3-7.0-WACCM_2018-2030_monthly_c210826.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/ndepdata/fndep_clm_f09_g17.CMIP6-SSP3-7.0-WACCM_2018-2030_monthly_c210826.nc [following]
# --2025-02-27 04:29:41--  https://storage.googleapis.com/neon-ncar/NEON/lnd/clm2/ndepdata/fndep_clm_f09_g17.CMIP6-SSP3-7.0-WACCM_2018-2030_monthly_c210826.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:29:41 ERROR 404: Not Found.
#
# Model datm missing file file1 = '/home/user/inputdata/cdeps/datm/ozone/O3_surface.f09_g17.CMIP6-SSP3-7.0-WACCM.001.monthly.201501-210012.nc'
# wget failed with output:  and errput --2025-02-27 04:29:41--  https://storage.neonscience.org/neon-ncar/NEON/cdeps/datm/ozone/O3_surface.f09_g17.CMIP6-SSP3-7.0-WACCM.001.monthly.201501-210012.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# ...
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:29:42 ERROR 404: Not Found.
#
# Model datm missing file mesh = '/home/user/inputdata/atm/datm7/topo_forcing/topodata_0.9x1.SCRIP.210520_ESMFmesh.nc'
# wget failed with output:  and errput --2025-02-27 04:29:42--  https://storage.neonscience.org/neon-ncar/NEON/atm/datm7/topo_forcing/topodata_0.9x1.SCRIP.210520_ESMFmesh.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/topo_forcing/topodata_0.9x1.SCRIP.210520_ESMFmesh.nc [following]
# --2025-02-27 04:29:42--  https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/topo_forcing/topodata_0.9x1.SCRIP.210520_ESMFmesh.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:29:42 ERROR 404: Not Found.
#
# Model datm missing file file1 = '/home/user/inputdata/atm/datm7/topo_forcing/topodata_0.9x1.25_USGS_070110_stream_c151201.nc'
# wget failed with output:  and errput --2025-02-27 04:29:42--  https://storage.neonscience.org/neon-ncar/NEON/atm/datm7/topo_forcing/topodata_0.9x1.25_USGS_070110_stream_c151201.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/topo_forcing/topodata_0.9x1.25_USGS_070110_stream_c151201.nc [following]
# --2025-02-27 04:29:43--  https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/topo_forcing/topodata_0.9x1.25_USGS_070110_stream_c151201.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:29:43 ERROR 404: Not Found.
#
# Model datm missing file file1 = '/home/user/inputdata/atm/datm7/CO2/fco2_datm_global_simyr_1750-2014_CMIP6_c180929.nc'
# wget failed with output:  and errput --2025-02-27 04:29:43--  https://storage.neonscience.org/neon-ncar/NEON/atm/datm7/CO2/fco2_datm_global_simyr_1750-2014_CMIP6_c180929.nc
# Resolving storage.neonscience.org (storage.neonscience.org)... 34.110.164.243
# Connecting to storage.neonscience.org (storage.neonscience.org)|34.110.164.243|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/CO2/fco2_datm_global_simyr_1750-2014_CMIP6_c180929.nc [following]
# --2025-02-27 04:29:43--  https://storage.googleapis.com/neon-ncar/NEON/atm/datm7/CO2/fco2_datm_global_simyr_1750-2014_CMIP6_c180929.nc
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.190.59, 142.250.190.91, 142.250.190.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.190.59|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-27 04:29:43 ERROR 404: Not Found.
#
# Model ctsm missing file stream_meshfile_popdens = '/home/user/inputdata/lnd/clm2/firedata/clmforc.Li_2017_HYDEv3.2_CMIP6_hdm_0.5x0_ESMFmesh_cdf5_100621.nc'
# Model ctsm missing file stream_fldfilename_popdens = '/home/user/inputdata/lnd/clm2/firedata/clmforc.Li_2018_SSP3_CMIP6_hdm_0.5x0.5_AVHRR_simyr1850-2100_c181205.nc'
# Model ctsm missing file stream_fldfilename_ndep = '/home/user/inputdata/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc'
# Model ctsm missing file stream_meshfile_ndep = '/home/user/inputdata/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc'
# Model ctsm missing file megan_factors_file = '/home/user/inputdata/atm/cam/chem/trop_mozart/emis/megan21_emis_factors_78pft_c20161108.nc'
# Model ctsm missing file stream_fldfilename_urbantv = '/home/user/inputdata/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1.25_simyr1849-2106_c160923.nc'
# Model ctsm missing file stream_meshfile_urbantv = '/home/user/inputdata/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1_ESMFmesh_cdf5_100621.nc'
# Model ctsm missing file stream_fldfilename_lightng = '/home/user/inputdata/atm/datm7/NASA_LIS/clmforc.Li_2016_climo1995-2013.360x720.lnfm_Total_NEONarea_c210625.nc'
# Model ctsm missing file stream_meshfile_lightng = '/home/user/inputdata/atm/datm7/NASA_LIS/ESMF_MESH.Li_2016.360x720.NEONarea_cdf5_c221104.nc'
# Model ctsm missing file fsurdat = '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc'
# Model ctsm missing file fsnowaging = '/home/user/inputdata/lnd/clm2/snicardata/snicar_drdt_bst_fit_60_c070416.nc'
# Model ctsm missing file fsnowoptics = '/home/user/inputdata/lnd/clm2/snicardata/snicar_optics_5bnd_c090915.nc'
# Model ctsm missing file paramfile = '/home/user/inputdata/lnd/clm2/paramdata/ctsm51_params.c211112.nc'
# Model ctsm missing file stream_fldfilename_ch4finundated = '/home/user/inputdata/lnd/clm2/paramdata/finundated_inversiondata_0.9x1.25_c170706.nc'
# Model ctsm missing file stream_meshfile_ch4finundated = '/home/user/inputdata/lnd/clm2/paramdata/finundated_inversiondata_0.9x1_ESMFmesh_cdf5_130621.nc'
# Model datm missing file mesh = '/home/user/inputdata/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc'
# Model datm missing file file1 = '/home/user/inputdata/atm/cam/chem/trop_mozart_aero/aero/aerodep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.001_2018-2030_monthly_0.9x1.25_c210826.nc'
# Model datm missing file file1 = '/home/user/inputdata/lnd/clm2/ndepdata/fndep_clm_f09_g17.CMIP6-SSP3-7.0-WACCM_2018-2030_monthly_c210826.nc'
# Model datm missing file file1 = '/home/user/inputdata/cdeps/datm/ozone/O3_surface.f09_g17.CMIP6-SSP3-7.0-WACCM.001.monthly.201501-210012.nc'
# Model datm missing file mesh = '/home/user/inputdata/atm/datm7/topo_forcing/topodata_0.9x1.SCRIP.210520_ESMFmesh.nc'
# Model datm missing file file1 = '/home/user/inputdata/atm/datm7/topo_forcing/topodata_0.9x1.25_USGS_070110_stream_c151201.nc'
# Model datm missing file file1 = '/home/user/inputdata/atm/datm7/CO2/fco2_datm_global_simyr_1750-2014_CMIP6_c180929.nc'
# Model ctsm missing file stream_meshfile_popdens = '/home/user/inputdata/lnd/clm2/firedata/clmforc.Li_2017_HYDEv3.2_CMIP6_hdm_0.5x0_ESMFmesh_cdf5_100621.nc'
# Model ctsm missing file stream_fldfilename_popdens = '/home/user/inputdata/lnd/clm2/firedata/clmforc.Li_2018_SSP3_CMIP6_hdm_0.5x0.5_AVHRR_simyr1850-2100_c181205.nc'
# Model ctsm missing file stream_fldfilename_ndep = '/home/user/inputdata/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc'
# wget failed with output:  and errput --2025-02-27 04:30:38--  ftp://ftp.cgd.ucar.edu/cesm/inputdata/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc
#            => ‘/home/user/inputdata/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc’
# Resolving ftp.cgd.ucar.edu (ftp.cgd.ucar.edu)... 128.117.13.41
# Connecting to ftp.cgd.ucar.edu (ftp.cgd.ucar.edu)|128.117.13.41|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /cesm/inputdata/lnd/clm2/ndepdata ... done.
# ==> SIZE fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc ... done.
#
# ==> PASV ... done.    ==> RETR fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc ...
# No such file ‘fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc’.
#
# Model ctsm missing file stream_meshfile_ndep = '/home/user/inputdata/share/meshes/fv0.9x1.25_141008_polemod_ESMFmesh.nc'
# Model ctsm missing file megan_factors_file = '/home/user/inputdata/atm/cam/chem/trop_mozart/emis/megan21_emis_factors_78pft_c20161108.nc'
# Model ctsm missing file stream_fldfilename_urbantv = '/home/user/inputdata/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1.25_simyr1849-2106_c160923.nc'
# Model ctsm missing file stream_meshfile_urbantv = '/home/user/inputdata/lnd/clm2/urbandata/CLM50_tbuildmax_Oleson_2016_0.9x1_ESMFmesh_cdf5_100621.nc'
# Model ctsm missing file stream_fldfilename_lightng = '/home/user/inputdata/atm/datm7/NASA_LIS/clmforc.Li_2016_climo1995-2013.360x720.lnfm_Total_NEONarea_c210625.nc'
# Model ctsm missing file stream_meshfile_lightng = '/home/user/inputdata/atm/datm7/NASA_LIS/ESMF_MESH.Li_2016.360x720.NEONarea_cdf5_c221104.nc'
# Model ctsm missing file fsurdat = '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc'
# wget failed with output:  and errput --2025-02-27 04:32:32--  ftp://ftp.cgd.ucar.edu/cesm/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc
#            => ‘/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc’
# Resolving ftp.cgd.ucar.edu (ftp.cgd.ucar.edu)... 128.117.13.41
# Connecting to ftp.cgd.ucar.edu (ftp.cgd.ucar.edu)|128.117.13.41|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /cesm/inputdata/lnd/clm2/surfdata_map/NEON ... done.
# ==> SIZE surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc ... done.
#
# ==> PASV ... done.    ==> RETR surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc ...
# No such file ‘surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc’.
#
# Model ctsm missing file fsnowaging = '/home/user/inputdata/lnd/clm2/snicardata/snicar_drdt_bst_fit_60_c070416.nc'
# Model ctsm missing file fsnowoptics = '/home/user/inputdata/lnd/clm2/snicardata/snicar_optics_5bnd_c090915.nc'
# Model ctsm missing file paramfile = '/home/user/inputdata/lnd/clm2/paramdata/ctsm51_params.c211112.nc'
# wget failed with output:  and errput --2025-02-27 04:32:35--  ftp://ftp.cgd.ucar.edu/cesm/inputdata/lnd/clm2/paramdata/ctsm51_params.c211112.nc
#            => ‘/home/user/inputdata/lnd/clm2/paramdata/ctsm51_params.c211112.nc’
# Resolving ftp.cgd.ucar.edu (ftp.cgd.ucar.edu)... 128.117.13.41
# Connecting to ftp.cgd.ucar.edu (ftp.cgd.ucar.edu)|128.117.13.41|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /cesm/inputdata/lnd/clm2/paramdata ... done.
# ==> SIZE ctsm51_params.c211112.nc ... done.
#
# ==> PASV ... done.    ==> RETR ctsm51_params.c211112.nc ...
# No such file ‘ctsm51_params.c211112.nc’.
#
# Model ctsm missing file stream_fldfilename_ch4finundated = '/home/user/inputdata/lnd/clm2/paramdata/finundated_inversiondata_0.9x1.25_c170706.nc'
# Model ctsm missing file stream_meshfile_ch4finundated = '/home/user/inputdata/lnd/clm2/paramdata/finundated_inversiondata_0.9x1_ESMFmesh_cdf5_130621.nc'
# Model datm missing file file1 = '/home/user/inputdata/atm/cam/chem/trop_mozart_aero/aero/aerodep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.001_2018-2030_monthly_0.9x1.25_c210826.nc'
# Model datm missing file file1 = '/home/user/inputdata/lnd/clm2/ndepdata/fndep_clm_f09_g17.CMIP6-SSP3-7.0-WACCM_2018-2030_monthly_c210826.nc'
# Model datm missing file file1 = '/home/user/inputdata/cdeps/datm/ozone/O3_surface.f09_g17.CMIP6-SSP3-7.0-WACCM.001.monthly.201501-210012.nc'
# wget failed with output:  and errput --2025-02-27 04:34:35--  ftp://ftp.cgd.ucar.edu/cesm/inputdata/cdeps/datm/ozone/O3_surface.f09_g17.CMIP6-SSP3-7.0-WACCM.001.monthly.201501-210012.nc
#            => ‘/home/user/inputdata/cdeps/datm/ozone/O3_surface.f09_g17.CMIP6-SSP3-7.0-WACCM.001.monthly.201501-210012.nc’
# Resolving ftp.cgd.ucar.edu (ftp.cgd.ucar.edu)... 128.117.13.41
# Connecting to ftp.cgd.ucar.edu (ftp.cgd.ucar.edu)|128.117.13.41|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /cesm/inputdata/cdeps/datm/ozone ...
# No such directory ‘cesm/inputdata/cdeps/datm/ozone’.
#
# Model datm missing file mesh = '/home/user/inputdata/atm/datm7/topo_forcing/topodata_0.9x1.SCRIP.210520_ESMFmesh.nc'
# Model datm missing file file1 = '/home/user/inputdata/atm/datm7/topo_forcing/topodata_0.9x1.25_USGS_070110_stream_c151201.nc'
# Model datm missing file file1 = '/home/user/inputdata/atm/datm7/CO2/fco2_datm_global_simyr_1750-2014_CMIP6_c180929.nc'
# Model ctsm missing file stream_fldfilename_ndep = '/home/user/inputdata/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc'
# ERROR from ftp server, trying next server
# Model ctsm missing file fsurdat = '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc'
# ERROR from ftp server, trying next server
# Model ctsm missing file paramfile = '/home/user/inputdata/lnd/clm2/paramdata/ctsm51_params.c211112.nc'
# ERROR from ftp server, trying next server
# Model datm missing file file1 = '/home/user/inputdata/cdeps/datm/ozone/O3_surface.f09_g17.CMIP6-SSP3-7.0-WACCM.001.monthly.201501-210012.nc'
# ERROR from ftp server, trying next server
# Model ctsm missing file stream_fldfilename_ndep = '/home/user/inputdata/lnd/clm2/ndepdata/fndep_clm_SSP370_b.e21.BWSSP370cmip6.f09_g17.CMIP6-SSP3-7.0-WACCM.002_1849-2101_monthly_0.9x1.25_c211216.nc'
# Model ctsm missing file fsurdat = '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_1x1_NEON_ABBY_hist_78pfts_CMIP6_simyr2000_c230111.nc'
# Model ctsm missing file paramfile = '/home/user/inputdata/lnd/clm2/paramdata/ctsm51_params.c211112.nc'
# Model datm missing file file1 = '/home/user/inputdata/cdeps/datm/ozone/O3_surface.f09_g17.CMIP6-SSP3-7.0-WACCM.001.monthly.201501-210012.nc'
# varname datafiles is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
# varname datafiles is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
# submit_jobs case.run
# Submit job case.run
# varname datafiles is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
# varname datafiles is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary

# %% [markdown]
# <br><br>
# The model is done running when you see the following line:
#
#
# > Submit job case.st_archive
#
#
# ### Congratulations! You've created and run CLM for the NEON tower you selected.
# Follow the steps below to see a few example plots from simulated data.
#
# **Note:** If your model simulation did not complete, there will likely be an error message with more information. If you do not understand the error message, please post your question on the [CTSM forum in the CESM Bulletin Board](https://bb.cgd.ucar.edu/cesm/forums/ctsm-clm-mosart-rtm.134/).

# %% [markdown]
# ***
# <h4> Optional </h4>
#
# If you would like to see additional and more advanced options for running NEON tower site simulations, many are listed in the python script you just executed. You can use the `--help` option to see more. <p>
#
# *Executing the below cell is optional and will print options available options in the `run_neon` python script*:

# %%
run_neon --help

# %% [markdown]
# ------------
#
# #### Below are a few additional tips for running simulations:
#
#  __Tip:__ You can run multiple neon sites at once by choosing multiple neon sites in the command line argument. For example:
# >
# >```
# >run_neon.py --neon-sites ABBY BART BLAN
# >```
#
# <br/>
#
#  __Tip:__ Use the `--overwrite` option to overwrite existing case directories.
# >
# >If you run a simulation for a NEON site that you have previously simulated, you will see the following error:
# >```
# >Case already exists in /home/user/CLM-NEON/ABBY.transient, not overwritting.
# >```
# >The overwrite option (e.g., adding `--overwrite` to the end of the `run_neon` command) can be used to avoid this error.
#
# <br/>
#
#  __Tip:__ You can run the above `run_neon` command in your terminal shell. You will need to specify the NEON site and the output-root path by replacing `<site>` and `<path>` below with the appropriate values:
#
# >```
# >run_neon.py --neon-sites <site> --output-root <path>
# >```
#
# <br/>
#
#  __Tip:__ The container will not overwrite existing files. If there are newer versions of a tutorial or input data you want to download, you must delete the existing tutorials or data first. You can do this by moving the files from the `Simulations` folder on your Desktop into the trash.
#
# <br/>
#
# **Note:** More information about setting up and modifying simulations, including changing model code, will be available in an upcoming tutorial.

# %% [markdown]
# ________
# <h2> 2. Explore CTSM model data </h2>
#
# *When your simulation completes, this step guides you through exploring the data.
# There are countless ways of analyzing and processing model data.
# The below steps step through where to find model data and creates a plot to visualize some model data.*
# ***

# %% [markdown]
# <h3> 2.1 Locate model data </h3>
#
# When a simulation completes, the data are stored in the `archive` directory. In this directory you will find files that include data for every day of the simulation, as well as files that average model variables monthly. <p>
#
# *Run the code below to see a subset of the files listed.*

# %%
# !ls $HOME/archive/$site.transient/lnd/hist/*2018*.nc |head -20

# %% [markdown]
# Notice that each line includes the location of the file (`/home/user/archive/{simulation_name}/lnd/hist/`) and file name. The file names are automatically generated and are composed of:
# * the simulation name, which includes:
#     * the NEON site
#     * the type of simulation
#         * The simulation you ran is "transient". This means the model was initialized and ran for the full length of available data. The initial conditions files for the transient tower simulations were created by cycling over 2018-2019 tower meteorological data.
# * the date of simulated data
#
# The files are saved in netcdf format (denoted with the `.nc` file extension), a file format commonly used for storing large, multi-dimensional scientific variables.
# Netcdf files are platform independent and self-describing; each file includes metadata that describes the data, including: **variables**, **dimensions**, and **attributes**. You can explore the files more in the NEON_Simple_Visualization_Tutorial
#
# The NEON tower simulations generate two types of files:
# * `*h0*`: Variables that are averaged monthly. One file is available for every month of the simulation. These files include hundreds of variables.
# * `*h1*`: Variables that are recorded every 30 minutes. Values are aggregated into one file for each day of the simulation. Each file includes 48 data points for selected variables.
#
# *Note that you can also find the model data in the 'Simulation' folder on your desktop, which was created as part of this tutorial.*
# ****

# %% [markdown]
# <h3>2.2 Visualize the output </h3>
#
# Below we create a plot of simulated soil temperature using a predefined function, `plot_soil_profile_timeseries`.
#
#
# The `plot_soil_profile_timeseries` function points to the simulated data files in your `archive` directory, extracts a variable (soil temperature, `TSOI`, in this case), and plots the soil profile. The y-axis shows soil depth and the x-axis shows time. Note that time is currently set for the year 2018. You can change the `year` variable below to plot different years from 2018 through 2020.

# %%
from neon_utils import plot_soil_profile_timeseries
sim_path = "/home/user/archive/"+neon_site+".transient/lnd/hist/"
case_name = neon_site+".transient.clm2"
year = 2018

plot_soil_profile_timeseries(sim_path, neon_site, case_name, 'TSOI', year)

# %% [markdown]
# You might also be interested in the soil moisture at this site. The `plot_soil_profile_timeseries` function can also plot soil moisture (`H2OSOI`). Run the below cell to see the soil moisture profile for 2018. You can change the `year` variable below to plot different years from 2018 through 2020.

# %%
sim_path = "/home/user/archive/"+neon_site+".transient/lnd/hist/"
case_name = neon_site+".transient.clm2"
year = 2018

plot_soil_profile_timeseries(sim_path, neon_site, case_name, 'H2OSOI', year)

# %% [markdown]
# ### Congratulations!
# You have now completed a NEON tower simulation, located the files, and made a plot from the simulation data.
#
# **Additional examples of visualizations and evaluation of your NEON simulation against NEON observations are available in the next tutorial, `NEON_Visualization_Tutorial`.**
